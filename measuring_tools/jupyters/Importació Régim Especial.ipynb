# %% [markdown]
# # Migrate
#
# How to use:
# - Set files path with variable `PATH`
# - Check file result and verify data
# - Create Instalacions from xls file indicated with variable `FILENAME`

# %%
import pandas as pd
import re
from tqdm import tqdm
from erppeek import Client
PATH = '/home/puig/Arranque Medidas RE (EDM)/'
FILENAME = 'Generadors_tipo_3_i_5_(RE12-RE).xlsx'
UPR_FILENAME = 'UPRSL_0189_20180201.54'
host = 'http://edm-erp.clients:28069'
user = 'edm_distri'
db = 'root'
#c = Client(host, db, user)
c = Client('http://chilla.clients:8069', 'chilla', 'root')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-0f7480525747> in <module>()
#      10 db = 'root'
#      11 #c = Client(host, db, user)
# ---> 12 c = Client('http://chilla.clients:8069', 'chilla', 'root')
#
# /home/puig/.virtualenvs/jupyter/local/lib/python2.7/site-packages/erppeek.pyc in __init__(self, server, db, user, password, transport, verbose)
#     437                 methods += _obsolete_methods.get(name) or ()
#     438             return Service(server, name, methods, transport, verbose=verbose)
# --> 439         self.server_version = ver = get_proxy('db').server_version()
#     440         self.major_version = re.match('\d+\.?\d*', ver).group()
#     441         float_version = float(self.major_version)
#
# /home/puig/.virtualenvs/jupyter/local/lib/python2.7/site-packages/erppeek.pyc in <lambda>(s, *args)
#     400                 return res
#     401         else:
# --> 402             wrapper = lambda s, *args: s._dispatch(name, args)
#     403         return _memoize(self, name, wrapper)
#     404
#
# /usr/lib/python2.7/xmlrpclib.pyc in __request(self, methodname, params)
#    1600             self.__handler,
#    1601             request,
# -> 1602             verbose=self.__verbose
#    1603             )
#    1604
#
# /usr/lib/python2.7/xmlrpclib.pyc in request(self, host, handler, request_body, verbose)
#    1281         for i in (0, 1):
#    1282             try:
# -> 1283                 return self.single_request(host, handler, request_body, verbose)
#    1284             except socket.error, e:
#    1285                 if i or e.errno not in (errno.ECONNRESET, errno.ECONNABORTED, errno.EPIPE):
#
# /usr/lib/python2.7/xmlrpclib.pyc in single_request(self, host, handler, request_body, verbose)
#    1309             self.send_host(h, host)
#    1310             self.send_user_agent(h)
# -> 1311             self.send_content(h, request_body)
#    1312
#    1313             response = h.getresponse(buffering=True)
#
# /usr/lib/python2.7/xmlrpclib.pyc in send_content(self, connection, request_body)
#    1457
#    1458         connection.putheader("Content-Length", str(len(request_body)))
# -> 1459         connection.endheaders(request_body)
#    1460
#    1461     ##
#
# /usr/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1036         else:
#    1037             raise CannotSendHeader()
# -> 1038         self._send_output(message_body)
#    1039
#    1040     def request(self, method, url, body=None, headers={}):
#
# /usr/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     880             msg += message_body
#     881             message_body = None
# --> 882         self.send(msg)
#     883         if message_body is not None:
#     884             #message_body was not a string (i.e. it is a file) and
#
# /usr/lib/python2.7/httplib.pyc in send(self, data)
#     842         if self.sock is None:
#     843             if self.auto_open:
# --> 844                 self.connect()
#     845             else:
#     846                 raise NotConnected()
#
# /usr/lib/python2.7/httplib.pyc in connect(self)
#     819         """Connect to the host and port specified in __init__."""
#     820         self.sock = self._create_connection((self.host,self.port),
# --> 821                                            self.timeout, self.source_address)
#     822
#     823         if self._tunnel_host:
#
# /usr/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# error: [Errno 110] Connection timed out

# %%
def merge_instalacions():
    cols = [
        'cp_upr', 'cif', 'representant', 'codi_representant', 'Ud Repre', 
        'desc', 'ree_code', 'x', 'y', 'z', 'k', 'l', 'y'
    ]
    df_upr = pd.read_csv(PATH + UPR_FILENAME, delimiter=';', names=cols)
    df_upr = df_upr.groupby(['representant', 'cif', 'Ud Repre']).aggregate({'desc': 'count'}).reset_index()
    df_instalacions = pd.read_excel(PATH + FILENAME, dtype={'titular': str}, converters={u'Pérdidas': percent_lows})
    df_instalacions = df_instalacions.merge(df_upr, how='left', on='Ud Repre')
    
    return df_instalacions

# %%
def get_province_from_cups(cups_id):
    """get ree province code from cups id"""
    cups = c.model('giscedata.cups.ps').browse(cups_id)
    return cups.id_provincia.ree_code

# %%
def percent_lows(low):
    return low * 100

# %% [markdown]
# # Verify file content

# %%
pd.read_excel(PATH + FILENAME, converters={u'Pérdidas': percent_lows}).sample(2)
# Out:
#                       cups       comptador                        titular  \
# 97  ES0189000048088503YF1F  ZIV00039344170            DAVID VALLES SANCHO
# 54  ES0189000035088502JC1F  ZIV00044545070  CUNICOLA LOS PEDREGALES, S.L.
#
#                                         cups_direcció tarifa  \
# 97  CL POLÍGONO 9 PARC. 130-149 (1) 44640 (Torreci...     RE
# 54   CL POLIGONO 32 PARC. 49 44564 (Mas de las Matas)     RE
#
#     potencia contractada  Tipus Ud Repre  Pérdidas
# 97                  10.0      5    FYEFG       0.0
# 54                   9.9      5   FYNEXU       0.0

# %% [markdown]
# # Create instalacions functions

# %%
def create_instalacions(data, c):
    """Create a Instalacions RE"""
    TIPOS = [('1', 'Tipo 1'),('2', 'Tipo 2'),('3', 'Tipo 3'),('4', 'Tipo 4'),('5', 'Tipo 5')]
    UNITATS_LECTURA = {'kWh': 1, 'Wh': 1000}
    
    uprs_obj = c.model('giscedata.re.uprs')
    re_obj = c.model('giscedata.re')
    cups_obj = c.model('giscedata.cups.ps')
    partner_obj = c.model('res.partner')
    instalacio_values = []
    upr_values = []
    undone = []
    df_upr = pd.read_csv(PATH + UPR_FILENAME, 
            delimiter=';', 
            names=[
                'cp_upr', 'cif', 'representant', 'codi_representant', 'unitat_programacio', 'desc', 'ree_code', 
                'x', 'y', 'z', 'k', 'l', 'y'
            ])
    
    for inst in tqdm(data.values()):
        cups_id = cups_obj.search([('name', '=', inst['cups'])])[0]
        tipo = inst['Tipus']
        provincia =  get_province_from_cups(cups_id)
        unitat_programacio = inst['Ud Repre']
        name_grouped = (re.sub("\(.*\)", "", inst['titular'])).strip()
        partner_id = partner_obj.search([('name', '=', name_grouped)])
        
        if not partner_id:
            undone.append({'cups': inst['cups'], 'name': inst['titular']})
            continue
        
        partner_id = partner_id[0]
        
        representant = inst['representant'] + '%'
        representant_id = partner_obj.search([('name', '=like', representant)])

        # Notes: 
        # - el nom de la instalació será el nom del titular.
        # - cap camp de la poteècia és obligatori.
        # - la potencia nominal serà la potència contractada del excel.
        
        instalacio_values.append({
            'name': inst['titular'], 
            'cups': cups_id, 
            'titular': partner_id, 
            'provincia': provincia, 
            'tipo': str(tipo), 
            'unidad_lec': UNITATS_LECTURA['kWh'], 
            'perdidas': inst[u'P\xe9rdidas'], 
            'p_ae': False, 
            'p_as': False, 
            'active': True, 
            'potencia_nominal': inst['potencia contractada'],
        })
        
        # Create instalacio
        instalacio = re_obj.create(instalacio_values[-1])
        instalacio_id = instalacio.id
        
        upr_values.append({
            'name': unitat_programacio, 
            'representante': representant_id[0],
            'inst_re': instalacio_id,
            'data_alta': '2000-01-01 00:00:00',
            'data_baixa': '3000-01-01 00:00:00' # any 3000
        })
        
        # Create UPR
        unitat_programacio = uprs_obj.create(upr_values[-1])
        unitat_programacio_id = unitat_programacio.id
        
        # Assign UPR
        instalacio.write({'uprs': [(6, 0, [unitat_programacio_id])]})
        
    return pd.DataFrame(instalacio_values), pd.DataFrame(upr_values), pd.DataFrame(undone)

# %% [markdown]
# # Create installations

# %%
# Parse file and exctract data
df_instalacions = merge_instalacions()
_dict = df_instalacions.T.to_dict()
data = create_instalacions(_dict, c)
# Out:
# 100%|██████████| 3/3 [00:05<00:00,  1.83s/it]

# %%
data[2]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data[0].loc[(data[0]['titular'] == False, ['cups', 'name', 'titular'])]
# Out:
#      cups                        name titular
# 12  59863  CATI RENOVABLES, C.B. - II   False
# 85  59774     PALAU MILIAN, S.L (9,2)   False
# 94  59864      QUEROL GUARDIOLA, S.L.   False

# %% [markdown]
# - El primer no ho troba perque és `CATI RENOVABLES, C.B.` (l'_script_ només suporta noms repetits diferenciats pel contingut d'un parèntesi final)
# - El segon i el tercer no els troba ja que els noms estan incomplerts:
#     - al segon li falta un punt final.
#     - al tercer li falta una U i un punt al final.

# %%
data[1][:2]
# Out:
#              data_alta           data_baixa  inst_re     name representante
# 0  2000-01-01 00:00:00  3000-01-01 00:00:00       17  FYEEXXI         64437
# 1  2000-01-01 00:00:00  3000-01-01 00:00:00       -1  FYEEXXI         64417

# %% [markdown]
# # Crear fitxer xml

# %%
def gen_doc(di, df):
    tg_obj = c.model('tg.profile')
    cups = 'ES0189000014088503RX1F'
    p_id = c.model('giscedata.polissa').search([('cups', '=', cups)])
    m_id = c.model('giscedata.lectures.comptador').search([('polissa', '=', p_id)])
    m_data = c.model('giscedata.lectures.comptador').read(m_id[0], ['concentrator', 'meter_tg_name'])
    root = ET.Element("Report", IdRpt="S02", IdPet="749963711", Version="3.1.c")
    doc = ET.SubElement(root, "Cnc", Id=m_data['concentrator'])                        
    subdoc = ET.SubElement(doc, "Cnc", Id=m_data['meter_tg_name'], Magn="1")
    tg_ids = tg_obj.search([('name', '=', m_data['meter_tg_name']), ('timestamp', '>=', di), ('timestamp', '<=', df)])
    for x in tg_obj.read(tg_ids, ['ai', 'ae', 'r1', 'r2', 'r3', 'r4', 'bc', 'timestamp']):
        ET.SubElement(subdoc, "S02", Fh=timestamp_to_xml_fh(x['timestamp']), AE=str(x['ae']), AI=str(x['ai']), R1=str(x['r1']), R2=str(x['r2']), Bc=x['bc'])
    tree = ET.ElementTree(root)
    tree.write("filename.xml")

# %% [markdown]
# # Crear curves

# %%
from erppeek import Client
cprod = Client('http://morella-erp.clients:8069', 'maestrazgo_distribucion', 'root')
cpreprod = Client('http://edm-erp.clients:28069', 'edm_distri', 'root')
# Out:
# Password for 'root': ········
# Password for 'root': ········

# %%
def get_registers_from_curve(tg, ree_contract_id, pol_id, curva_id, measures, arrastres):
    re_obj = cpreprod.model('giscedata.re')
    upr_obj = cpreprod.model('giscedata.re.uprs')
    agcl_obj = cpreprod.model('giscedata.perfils.agcl')
    
    year, month, day = tg['timestamp'][:10].split('-')
    hour = tg['timestamp'][11:13]
    name = year + month + day + hour
    
    ree_contract = re_obj.read(ree_contract_id, ['provincia', 'cups', 'uprs', 'tipo'])
    upr_name = upr_obj.read(ree_contract['uprs'][0], ['name'])
    uid = 1
    distribuidora = agcl_obj.default_distribuidora(uid)
    
    """
    lectura_real: (lectura * magnitud) / 1000 (W -> kW)
    perdues: perdues del contracte per cada magnitud (generalment 0)
    lectura: int(lectura) (truncada)
    arrastre: arrastre_anterior += part_decimal_lectura_real
    """
    res = []
    _tmp_vals = {
        'name': name, 'year': year, 'month': month, 'day': day, 
        'cups': ree_contract['cups'][1], 'provincia': ree_contract['provincia'], 'tipo': ree_contract['tipo'],
        'hour': int(hour), 'upr': upr_name, 'estacio': 1, 'distribuidora': distribuidora,
        'curva': curva_id
    }
    perdues_config = 0
    perdues = dict.fromkeys(measures, 0)
    for measure in measures:
        vals = _tmp_vals.copy()
        vals['magnitud'] = measure
        lectura = (tg['ai']  * tg['magn']) / 1000
        vals['lectura_real'] = lectura
        vals['perdues'] = perdues[measure] * perdues_config
        lectura -= lectura * vals['perdues']
        lectura += arrastres[measure]
        aprox = int(abs(round(lectura)))
        arrastres[measure] = lectura - aprox
        if abs(arrastres[measure]) > 1:
            aprox += int(arrastres[measure])
            arrastres[magnitud] -= int(arrastres[measure])
        vals['arrastre'] = arrastres[measure]
        vals['lectura'] = aprox
        #vals['estacio']
        res.append(vals)
    return res
    # TODO: get_estacio
    # TODO: comprovador d'hores totals!!!

# %%
# ae (active export) del model tg.profile = as (activa saliente)
# ai (active input) del model tg.profile = ae (activa entrante)

from datetime import datetime
def create_curve(di, df):
    pol_obj = cpreprod.model('giscedata.polissa')
    meter_obj = cpreprod.model('giscedata.lectures.comptador')
    prof_obj = cprod.model('tg.profile')
    re_curva_obj = cpreprod.model('giscedata.re.curva')
    re_curva_lectura_obj = cpreprod.model('giscedata.re.curva.lectura')
    cups = 'ES0189000014088503RX1F'
    ree_contract_id = 167
    p_id = pol_obj.search([('cups', '=', cups)])
    m_id = meter_obj.search([('polissa', '=', p_id)])
    meter_name = meter_obj.build_name_tg(m_id)
    tg_ids = prof_obj.search([('name', '=', meter_name), ('timestamp', '>=', di), ('timestamp', '<=', df)])
    
    vals = {
        'name': 'Curva creada el: {}'.format(datetime.now().strftime('%d/%m/%Y %H:%M:%S')),
        'inici': di,
        'final': df,
        'inst_re': ree_contract_id,
        'compact': True
    }
    curva_id = re_curva_obj.create(vals)
    measures = ['AE', 'AS', 'R1', 'R2', 'R3', 'R4']
    arrastres = dict.fromkeys(measures, 0)
    to_check = []
    for x, tg in enumerate(prof_obj.read(tg_ids, ['ai', 'ae', 'r1', 'r2', 'r3', 'r4', 'timestamp', 'magn'])):
        a = get_registers_from_curve(tg, ree_contract_id, p_id, curva_id, measures, arrastres)
        for elem in a:
            print '{} \n'.format(elem)
            to_check.append(elem)
            #re_curva_lectura_obj.create(elem)
    
    # Validator hours
    """diff = datetime.strptime(df, '%Y-%m-%d %H:%M:%S') - datetime.strptime(di, '%Y-%m-%d %H:%M:%S')
    total = (diff.seconds) / 3600 * 6
    assert total == len(to_check), 'total {} vs check {}'.format(total, len(to_check))"""

# %%
create_curve('2018-07-01 01:00:00', '2018-08-01 00:00:00')
# Out:
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018080100', 'hour': 0, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '08', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.001, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '01', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073123', 'hour': 23, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.002, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073122', 'hour': 22, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.001, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073121', 'hour': 21, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073120', 'hour': 20, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073119', 'hour': 19, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073118', 'hour': 18, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073117', 'hour': 17, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073116', 'hour': 16, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073115', 'hour': 15, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073114', 'hour': 14, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073113', 'hour': 13, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073112', 'hour': 12, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073111', 'hour': 11, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073110', 'hour': 10, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AE', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'AS', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R1', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R2', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R3', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
#
# {'lectura': 0, 'provincia': 'CS', 'name': '2018073109', 'hour': 9, 'perdues': 0, 'distribuidora': '0189', 'magnitud': 'R4', 'month': '07', 'curva': <Record 'giscedata.re.curva,40'>, 'estacio': 1, 'arrastre': 0.003, 'year': '2018', 'lectura_real': 0.0, 'cups': 'ES0189000014088503RX1F', 'upr': {'name': 'FYGAC', 'id': 161}, 'day': '31', 'tipo': '5'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-062be69e10dc> in <module>()
# ----> 1 create_curve('2018-07-01 01:00:00', '2018-08-01 00:00:00')
#
# <ipython-input-65-bf7fea357e7e> in create_curve(di, df)
#      28     to_check = []
#      29     for x, tg in enumerate(prof_obj.read(tg_ids, ['ai', 'ae', 'r1', 'r2', 'r3', 'r4', 'timestamp', 'magn'])):
# ---> 30         a = get_registers_from_curve(tg, ree_contract_id, p_id, curva_id, measures, arrastres)
#      31         for elem in a:
#      32             print '{} \n'.format(elem)
#
# <ipython-input-44-55474f148686> in get_registers_from_curve(tg, ree_contract_id, pol_id, curva_id, measures, arrastres)
#      11     upr_name = upr_obj.read(ree_contract['uprs'][0], ['name'])
#      12     uid = 1
# ---> 13     distribuidora = agcl_obj.default_distribuidora(uid)
#      14
#      15     """
#
# /home/puig/.virtualenvs/jupyter/local/lib/python2.7/site-packages/erppeek.pyc in wrapper(self, *params, **kwargs)
#    1192             if 'context' not in kwargs:
#    1193                 kwargs['context'] = self.client.context
# -> 1194             return self._execute(attr, *params, **kwargs)
#    1195         return _memoize(self, attr, wrapper, (self._name, attr))
#    1196
#
# /home/puig/.virtualenvs/jupyter/local/lib/python2.7/site-packages/erppeek.pyc in execute(self, obj, method, *params, **kwargs)
#     710         for item in kwargs.items():
#     711             print('Ignoring: %s = %r' % item)
# --> 712         res = self._execute(obj, method, *params)
#     713         if ordered:
#     714             # The results are not in the same order as the ids
#
# /home/puig/.virtualenvs/jupyter/local/lib/python2.7/site-packages/erppeek.pyc in <lambda>(s, *args)
#     400                 return res
#     401         else:
# --> 402             wrapper = lambda s, *args: s._dispatch(name, args)
#     403         return _memoize(self, name, wrapper)
#     404
#
# /usr/lib/python2.7/xmlrpclib.pyc in __request(self, methodname, params)
#    1600             self.__handler,
#    1601             request,
# -> 1602             verbose=self.__verbose
#    1603             )
#    1604
#
# /usr/lib/python2.7/xmlrpclib.pyc in request(self, host, handler, request_body, verbose)
#    1281         for i in (0, 1):
#    1282             try:
# -> 1283                 return self.single_request(host, handler, request_body, verbose)
#    1284             except socket.error, e:
#    1285                 if i or e.errno not in (errno.ECONNRESET, errno.ECONNABORTED, errno.EPIPE):
#
# /usr/lib/python2.7/xmlrpclib.pyc in single_request(self, host, handler, request_body, verbose)
#    1311             self.send_content(h, request_body)
#    1312
# -> 1313             response = h.getresponse(buffering=True)
#    1314             if response.status == 200:
#    1315                 self.verbose = verbose
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
